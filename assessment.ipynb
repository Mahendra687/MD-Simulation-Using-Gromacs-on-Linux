# %% [markdown]
# # **Assessment of the MD-Production**

# %%
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %%
potential = np.genfromtxt([i for i in open('potential.xvg').read().splitlines()
    if not i.startswith(('#','@'))])

# %%
plt.plot(*potential.T, color='blue')
plt.xlabel('Time-[ps]')
plt.ylabel('[kJ/mol]')
plt.title("Potential Energy")
plt.show()

# %%
temperature = np.genfromtxt([i for i in open('temperature.xvg').read().splitlines()
    if not i.startswith(('#','@'))])

# %%
plt.plot(*temperature.T, color='orange')
plt.xlabel('Time-[ps]')
plt.ylabel('K')
plt.title("Temperature")
plt.show()

# %%
pressure = np.genfromtxt([i for i in open('pressure.xvg').read().splitlines()
    if not i.startswith(('#','@'))])




plt.plot(*pressure.T,color='red')
plt.xlabel('Time-[ps]')
plt.ylabel('[Bar]')
plt.title("Pressure")
plt.show()

# %%
density = np.genfromtxt([i for i in open('density.xvg').read().splitlines()
    if not i.startswith(('#','@'))])


plt.plot(*density.T, color='green')
plt.xlabel('Time-[ps]')
plt.ylabel('(kg/m^3)')
plt.title("Density")
plt.show()

# %%
rmsd = np.genfromtxt([i for i in open('rmsd.xvg').read().splitlines()
    if not i.startswith(('#','@'))])


plt.plot(*rmsd.T, color='skyblue')
plt.xlabel('Time-[ns]')
plt.ylabel('RMSD [nm]')
plt.title("RMSD")
plt.show()

# %%
rmsd = np.genfromtxt([i for i in open('rmsd_one.xvg').read().splitlines()
    if not i.startswith(('#','@'))])


plt.plot(*rmsd.T, color='skyblue')
plt.xlabel('Time-[ns]')
plt.ylabel('RMSD [nm]')
plt.title("RMSD")
plt.show()

# %%
rmsd = np.genfromtxt([i for i in open('rmsf.xvg').read().splitlines()
    if not i.startswith(('#','@'))])


plt.plot(*rmsd.T, color='blue')
plt.xlabel('Atom')
plt.ylabel('[nm]')
plt.title("RMS fluctuation")
plt.show()

# %%
hb = np.genfromtxt([i for i in open('hb.xvg').read().splitlines()
    if not i.startswith(('#','@'))])

plt.plot(*hb.T, color='lightgreen')
plt.xlabel('Time-[ns]')
plt.ylabel('Number');
plt.title("Hydrogen Bonds")
# Out:
# Text(0.5, 1.0, 'Hydrogen Bonds')

# %%
gyrate = np.genfromtxt([i for i in open('gyrate.xvg').read().splitlines()
    if not i.startswith(('#','@'))])




plt.plot(*gyrate.T, color='lightblue')
plt.xlabel('Time-[ps]')
plt.ylabel('Rg-[nm]')
plt.title("Radius of Gyration")
plt.show()

# %%
energy = np.genfromtxt([i for i in open('energy.xvg').read().splitlines()
    if not i.startswith(('#','@'))])

plt.plot(*energy.T, color='blue')
plt.xlabel('Time-[ps]')
plt.ylabel('[K]');
plt.title("Gromacs Energies")
plt.show()

# %%
energy = np.genfromtxt([i for i in open('energy1.xvg').read().splitlines()
    if not i.startswith(('#','@'))])

plt.plot(*energy.T, color='blue')
plt.xlabel('Time-[ps]')
plt.ylabel('[K]');
plt.title("Gromacs Energies")
plt.show()

# %%
residue = np.genfromtxt([i for i in open('residuetable.xvg').read().splitlines()
    if not i.startswith(('#','@'))])

plt.plot(*residue.T, color='blue')
plt.xlabel('Time-[ps]')
plt.ylabel('[K]');
plt.title("Gromacs Energies")
plt.show()

# %%
dist = np.genfromtxt([i for i in open('/content/mindist_output.xvg').read().splitlines()
    if not i.startswith(('#','@'))])

plt.plot(*dist.T, color='blue')
plt.xlabel('Time-[ps]')
plt.ylabel('Distance-[nm]');
plt.title("Min Distance")
plt.show()
